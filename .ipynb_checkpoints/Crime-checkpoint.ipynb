# %%
using DataFrames
using Gadfly
# Out:
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Rmath.ji for module Rmath.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\GZip.ji for module GZip.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\FileIO.ji for module FileIO.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Gadfly.ji for module Gadfly.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Codecs.ji for module Codecs.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Compose.ji for module Compose.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Iterators.ji for module Iterators.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\DataStructures.ji for module DataStructures.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Measures.ji for module Measures.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Showoff.ji for module Showoff.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Distributions.ji for module Distributions.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\PDMats.ji for module PDMats.
# WARNING: New definition
#     color_discrete_manual(ColorTypes.Color...) at C:\Users\User\.julia\v0.4\Gadfly\src\scale.jl:530
# is ambiguous with:
#     color_discrete_manual(AbstractString...) at C:\Users\User\.julia\v0.4\Gadfly\src\scale.jl:527.
# To fix, define
#     color_discrete_manual()
# before the new definition.
# WARNING: New definition
#     color_discrete_manual(Array, ColorTypes.Color...)
# is ambiguous with:
#     color_discrete_manual(Array, AbstractString...).
# To fix, define
#     color_discrete_manual(Array)
# before the new definition.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Hexagons.ji for module Hexagons.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Contour.ji for module Contour.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\FixedSizeArrays.ji for module FixedSizeArrays.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Loess.ji for module Loess.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Distances.ji for module Distances.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Calculus.ji for module Calculus.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\ForwardDiff.ji for module ForwardDiff.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Optim.ji for module Optim.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\PositiveFactorizations.ji for module PositiveFactorizations.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\KernelDensity.ji for module KernelDensity.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Ratios.ji for module Ratios.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\Interpolations.ji for module Interpolations.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\WoodburyMatrices.ji for module WoodburyMatrices.
# INFO: Recompiling stale cache file C:\Users\User\.julia\lib\v0.4\AxisAlgorithms.ji for module AxisAlgorithms.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at C:\Users\User\.julia\v0.4\WoodburyMatrices\src\SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at C:\Users\User\.julia\v0.4\DataArrays\src\operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at C:\Users\User\.julia\v0.4\WoodburyMatrices\src\SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at C:\Users\User\.julia\v0.4\DataArrays\src\operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at C:\Users\User\.julia\v0.4\WoodburyMatrices\src\SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at C:\Users\User\.julia\v0.4\DataArrays\src\operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at C:\Users\User\.julia\v0.4\WoodburyMatrices\src\SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at C:\Users\User\.julia\v0.4\DataArrays\src\operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.

# %%
# load data
crime = readtable("crime.csv")
# Out:
# 1542×11 DataFrames.DataFrame
# │ Row  │ County   │ Year │ Population │ Index_Count │ Index_Rate │
# ├──────┼──────────┼──────┼────────────┼─────────────┼────────────┤
# │ 1    │ "Albany" │ 2015 │ 308613     │ 8224        │ 2664.8     │
# │ 2    │ "Albany" │ 2014 │ 308166     │ 9157        │ 2971.5     │
# │ 3    │ "Albany" │ 2013 │ 306300     │ 9455        │ 3086.8     │
# │ 4    │ "Albany" │ 2012 │ 305204     │ 9971        │ 3267.0     │
# │ 5    │ "Albany" │ 2011 │ 305571     │ 10725       │ 3509.8     │
# │ 6    │ "Albany" │ 2010 │ 295267     │ 11036       │ 3737.6     │
# │ 7    │ "Albany" │ 2009 │ 298400     │ 10613       │ 3556.6     │
# │ 8    │ "Albany" │ 2008 │ 299789     │ 10750       │ 3585.9     │
# │ 9    │ "Albany" │ 2007 │ 297154     │ 10584       │ 3561.8     │
# │ 10   │ "Albany" │ 2006 │ 298210     │ 11935       │ 4002.2     │
# │ 11   │ "Albany" │ 2005 │ 298859     │ 12119       │ 4055.1     │
# ⋮
# │ 1531 │ "Yates"  │ 2001 │ 24666      │ 348         │ 1410.8     │
# │ 1532 │ "Yates"  │ 2000 │ 25608      │ 348         │ 1359.0     │
# │ 1533 │ "Yates"  │ 1999 │ 24230      │ 441         │ 1820.1     │
# │ 1534 │ "Yates"  │ 1998 │ 24188      │ 429         │ 1773.6     │
# │ 1535 │ "Yates"  │ 1997 │ 23866      │ 487         │ 2040.6     │
# │ 1536 │ "Yates"  │ 1996 │ 23930      │ 497         │ 2076.9     │
# │ 1537 │ "Yates"  │ 1995 │ 23867      │ 551         │ 2308.6     │
# │ 1538 │ "Yates"  │ 1994 │ 23302      │ 608         │ 2609.2     │
# │ 1539 │ "Yates"  │ 1993 │ 23339      │ 553         │ 2369.4     │
# │ 1540 │ "Yates"  │ 1992 │ 22970      │ 548         │ 2385.7     │
# │ 1541 │ "Yates"  │ 1991 │ 22894      │ 678         │ 2961.5     │
# │ 1542 │ "Yates"  │ 1990 │ 22810      │ 507         │ 2222.7     │
#
# │ Row  │ Violent_Count │ Violent_Rate │ Property_Count │ Property_Rate │
# ├──────┼───────────────┼──────────────┼────────────────┼───────────────┤
# │ 1    │ 1005          │ 325.7        │ 7219           │ 2339.2        │
# │ 2    │ 995           │ 322.9        │ 8162           │ 2648.6        │
# │ 3    │ 1002          │ 327.1        │ 8453           │ 2759.7        │
# │ 4    │ 1012          │ 331.6        │ 8959           │ 2935.4        │
# │ 5    │ 1163          │ 380.6        │ 9562           │ 3129.2        │
# │ 6    │ 1182          │ 400.3        │ 9854           │ 3337.3        │
# │ 7    │ 1289          │ 432.0        │ 9324           │ 3124.7        │
# │ 8    │ 1356          │ 452.3        │ 9394           │ 3133.5        │
# │ 9    │ 1468          │ 494.0        │ 9116           │ 3067.8        │
# │ 10   │ 1545          │ 518.1        │ 10390          │ 3484.1        │
# │ 11   │ 1615          │ 540.4        │ 10504          │ 3514.7        │
# ⋮
# │ 1531 │ 19            │ 77.0         │ 329            │ 1333.8        │
# │ 1532 │ 26            │ 101.5        │ 322            │ 1257.4        │
# │ 1533 │ 32            │ 132.1        │ 409            │ 1688.0        │
# │ 1534 │ 22            │ 91.0         │ 407            │ 1682.7        │
# │ 1535 │ 35            │ 146.7        │ 452            │ 1893.9        │
# │ 1536 │ 30            │ 125.4        │ 467            │ 1951.5        │
# │ 1537 │ 60            │ 251.4        │ 491            │ 2057.2        │
# │ 1538 │ 52            │ 223.2        │ 556            │ 2386.1        │
# │ 1539 │ 59            │ 252.8        │ 494            │ 2116.6        │
# │ 1540 │ 67            │ 291.7        │ 481            │ 2094.0        │
# │ 1541 │ 57            │ 249.0        │ 621            │ 2712.5        │
# │ 1542 │ 34            │ 149.1        │ 473            │ 2073.7        │
#
# │ Row  │ Firearm_Count │ Firearm_Rate │
# ├──────┼───────────────┼──────────────┤
# │ 1    │ 111           │ 36.0         │
# │ 2    │ 146           │ 47.4         │
# │ 3    │ 150           │ 49.0         │
# │ 4    │ 137           │ 44.9         │
# │ 5    │ 196           │ 64.1         │
# │ 6    │ 154           │ 52.2         │
# │ 7    │ 191           │ 64.0         │
# │ 8    │ 238           │ 79.4         │
# │ 9    │ 208           │ 70.0         │
# │ 10   │ 200           │ 67.1         │
# │ 11   │ 260           │ 87.0         │
# ⋮
# │ 1531 │ 0             │ 0.0          │
# │ 1532 │ 1             │ 3.9          │
# │ 1533 │ 0             │ 0.0          │
# │ 1534 │ 1             │ 4.1          │
# │ 1535 │ 0             │ 0.0          │
# │ 1536 │ 1             │ 4.2          │
# │ 1537 │ 2             │ 8.4          │
# │ 1538 │ 2             │ 8.6          │
# │ 1539 │ 2             │ 8.6          │
# │ 1540 │ 2             │ 8.7          │
# │ 1541 │ 1             │ 4.4          │
# │ 1542 │ 2             │ 8.8          │

# %% [markdown]
# First, let's see what the data look like.

# %%
plot(crime,x=:Year,y=:Index_Rate,color=:County,Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# Looks like some counties didn't report their data every year - especially, the large ones.

# %%
large_counties = Set((crime[:County])[crime[:Index_Count].>1e5])
# Out:
# Set(UTF8String["Queens","New York","Bronx","Kings"])

# %% [markdown]
# Let's check that assumption. Which counties didn't report their data all years?

# %%
counties = Set((crime[:County])) # No duplicates
reporting_counties = String[]
nonreporting_counties = String[]

for county in counties
    # println("$county reported for $(length(crime[crime[:County].==county,:County])) years.")
    if length(crime[crime[:County].==county,:County]) == 26
        push!(reporting_counties, county)
    else
        push!(nonreporting_counties, county)
    end
end
nonreporting_counties
# Out:
# WARNING:
# 7-element Array{AbstractString,1}:
#  "Kings"
#  "New York"
#  "St Lawrence"
#  "Richmond"
#  "Queens"
#  "Bronx"
#  "St. Lawrence"
# Base.String is deprecated, use AbstractString instead.
#   likely near In[12]:2
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near In[12]:3

# %%
reported_crime_all_years = Array(Bool, size(crime,1)) # an array of boolean values
for (i,county) in enumerate(crime[:County]) # i is the index
    reported_crime_all_years[i] = ~(county in nonreporting_counties)
end
reported_crime_all_years
# Out:
# 1542-element Array{Bool,1}:
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#     ⋮
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true
#  true

# %% [markdown]
# Let's delete data from the counties that didn't always report it.

# %%
crime = crime[reported_crime_all_years,:]

# %% [markdown]
# Let's see what this cleaner data set looks like.

# %%
plot(crime,x=:Year,y=:Index_Count,color=:County,Geom.line)

# %%
plot(crime,x=:Year,y=:Index_Count,color=:County,Geom.bar, Coord.cartesian(xmin=1990, xmax=2015, ymin=0, ymax=5e5))

# %%
# just Tompkins county
tompkins = crime[crime[:County].=="Tompkins",:]

# %%
plot(tompkins,x=:Year,y=:Index_Rate,color=:County,Geom.point)
