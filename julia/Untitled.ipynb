# %%
using LowRankModels
# Out:
# ArgumentError: Package LowRankModels not found in current path:
# - Run `import Pkg; Pkg.add("LowRankModels")` to install the LowRankModels package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:893
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
import Pkg; Pkg.add("LowRankModels")
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [======>                                  ]  12.9 %
#     Fetching: [===========
#     Fetching: [=================>                       ]  40.1 %
# Fetching: [========================================>]  99.9 %               ]  61.5 % [===============================>         ]  75.2 %Fetching: [===================================>     ]  86.5 %
#   Resolving package versions...
#   Installed LaTeXStrings ───── v1.2.0
#   Installed Juno ───────────── v0.8.4
#   Installed IJulia ─────────── v1.21.4
#   Installed DataFrames ─────── v0.13.1
#   Installed Atom ───────────── v0.12.23
#   Installed Plots ──────────── v1.6.7
#   Installed CodecZlib ──────── v0.7.0
#   Installed InternedStrings ── v0.7.0
#   Installed JuliaFormatter ─── v0.8.2
#   Installed Compat ─────────── v2.2.1
#   Installed Showoff ────────── v0.3.2
# ...
